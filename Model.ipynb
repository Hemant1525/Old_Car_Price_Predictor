# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/hemantjain/Old_Car_Price_Prediction_Model/car_price.csv")

# %%
df.head()
# Out:
#                                  car_name  Kms_driven fuel_type Transmission  \
# 0  Jeep Compass 2.0 Longitude Option BSIV       86226    Diesel       Manual
# 1            Renault Duster RXZ Turbo CVT       13248    Petrol    Automatic
# 2                      Toyota Camry 2.5 G       60343    Petrol    Automatic
# 3                       Honda Jazz VX CVT       26696    Petrol    Automatic
# 4        Volkswagen Polo 1.2 MPI Highline       69414    Petrol       Manual
#
#    Ownership  Manufacture  Engine_cc  Seats car_prices_in_rupee  \
# 0          1         2017       1956      5          10.03 Lakh
# 1          1         2021       1330      5          12.83 Lakh
# 2          1         2016       2494      5          16.40 Lakh
# 3          1         2018       1199      5           7.77 Lakh
# 4          1         2016       1199      5           5.15 Lakh
#
#    Price_in_rupees
# 0          1003000
# 1          1283000
# 2          1640000
# 3           777000
# ...

# %%
df.drop(['car_prices_in_rupee'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                  car_name  Kms_driven fuel_type Transmission  \
# 0  Jeep Compass 2.0 Longitude Option BSIV       86226    Diesel       Manual
# 1            Renault Duster RXZ Turbo CVT       13248    Petrol    Automatic
# 2                      Toyota Camry 2.5 G       60343    Petrol    Automatic
# 3                       Honda Jazz VX CVT       26696    Petrol    Automatic
# 4        Volkswagen Polo 1.2 MPI Highline       69414    Petrol       Manual
#
#    Ownership  Manufacture  Engine_cc  Seats  Price_in_rupees
# 0          1         2017       1956      5          1003000
# 1          1         2021       1330      5          1283000
# 2          1         2016       2494      5          1640000
# 3          1         2018       1199      5           777000
# 4          1         2016       1199      5           515000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   car_name         5512 non-null   str
#  1   Kms_driven       5512 non-null   int64
#  2   fuel_type        5512 non-null   str
#  3   Transmission     5512 non-null   str
#  4   Ownership        5512 non-null   int64
#  5   Manufacture      5512 non-null   int64
#  6   Engine_cc        5512 non-null   int64
#  7   Seats            5512 non-null   int64
#  8   Price_in_rupees  5512 non-null   int64
# dtypes: int64(6), str(3)
# memory usage: 592.6 KB

# %% [markdown]
# # LABLE ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # CAR_NAME

# %%
car_name_le = LabelEncoder()
df['car_name'] = car_name_le.fit_transform(df['car_name'])

# %% [markdown]
# # FUEL_TYPE

# %%
fuel_type_le = LabelEncoder()
df['fuel_type'] = fuel_type_le.fit_transform(df['fuel_type'])

# %% [markdown]
# # TRANSMISSION

# %%
Transmission_le = LabelEncoder()
df['Transmission'] = Transmission_le.fit_transform(df['Transmission'])

# %%
df.head()
# Out:
#    car_name  Kms_driven  fuel_type  Transmission  Ownership  Manufacture  \
# 0       743       86226          1             1          1         2017
# 1      1444       13248          4             0          1         2021
# 2      1706       60343          4             0          1         2016
# 3       385       26696          4             0          1         2018
# 4      1831       69414          4             1          1         2016
#
#    Engine_cc  Seats  Price_in_rupees
# 0       1956      5          1003000
# 1       1330      5          1283000
# 2       2494      5          1640000
# 3       1199      5           777000
# 4       1199      5           515000

# %%
df.isnull().sum()
# Out:
# car_name           0
# Kms_driven         0
# fuel_type          0
# Transmission       0
# Ownership          0
# Manufacture        0
# Engine_cc          0
# Seats              0
# Price_in_rupees    0
# dtype: int64

# %%
df.describe()
# Out:
#           car_name     Kms_driven    fuel_type  Transmission    Ownership  \
# count  5512.000000    5512.000000  5512.000000   5512.000000  5512.000000
# mean    916.880443   63211.888062     2.613026      0.718795     1.421807
# std     516.405197   41844.131167     1.510117      0.449628     0.703092
# min       0.000000     250.000000     0.000000      0.000000     0.000000
# 25%     481.750000   33151.750000     1.000000      0.000000     1.000000
# 50%     970.500000   59000.000000     4.000000      1.000000     1.000000
# 75%    1298.000000   84265.250000     4.000000      1.000000     2.000000
# max    1895.000000  560000.000000     4.000000      1.000000     5.000000
#
#        Manufacture    Engine_cc        Seats  Price_in_rupees
# count  5512.000000  5512.000000  5512.000000     5.512000e+03
# mean   2015.455552  1532.299710     5.250726     1.162510e+06
# std       3.927974   579.210876     0.720075     1.969919e+06
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   car_name         5512 non-null   int64
#  1   Kms_driven       5512 non-null   int64
#  2   fuel_type        5512 non-null   int64
#  3   Transmission     5512 non-null   int64
#  4   Ownership        5512 non-null   int64
#  5   Manufacture      5512 non-null   int64
#  6   Engine_cc        5512 non-null   int64
#  7   Seats            5512 non-null   int64
#  8   Price_in_rupees  5512 non-null   int64
# dtypes: int64(9)
# memory usage: 387.7 KB

# %%
x = df.iloc[:,:-1]
y = df['Price_in_rupees']

# %%
x
# Out:
#       car_name  Kms_driven  fuel_type  Transmission  Ownership  Manufacture  \
# 0          743       86226          1             1          1         2017
# 1         1444       13248          4             0          1         2021
# 2         1706       60343          4             0          1         2016
# 3          385       26696          4             0          1         2018
# 4         1831       69414          4             1          1         2016
# ...        ...         ...        ...           ...        ...          ...
# 5507        82       45000          1             0          1         2018
# 5508        79       29000          4             0          2         2015
# 5509       720       90000          1             0          2         2013
# 5510        74       79000          1             0          3         2015
# 5511        62       42000          1             0          2         2017
#
#       Engine_cc  Seats
# 0          1956      5
# ...

# %%
y
# Out:
# 0       1003000
# 1       1283000
# 2       1640000
# 3        777000
# 4        515000
#          ...
# 5507    2890000
# 5508    6490000
# 5509    1375000
# 5510    2990000
# 5511    3190000
# Name: Price_in_rupees, Length: 5512, dtype: int64

# %% [markdown]
# # SCALLING

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
x = pd.DataFrame(ss.fit_transform(x), columns=x.columns)

# %%
x
# Out:
#       car_name  Kms_driven  fuel_type  Transmission  Ownership  Manufacture  \
# 0    -0.336744    0.550046  -1.068243      0.625473  -0.599986     0.393228
# 1     1.020841   -1.194156   0.918538     -1.598790  -0.599986     1.411657
# 2     1.528240   -0.068568   0.918538     -1.598790  -0.599986     0.138621
# 3    -1.030061   -0.872744   0.918538     -1.598790  -0.599986     0.647835
# 4     1.770320    0.148233   0.918538      0.625473  -0.599986     0.138621
# ...        ...         ...        ...           ...        ...          ...
# 5507 -1.616862   -0.435271  -1.068243     -1.598790  -0.599986     0.647835
# 5508 -1.622672   -0.817677   0.918538     -1.598790   0.822432    -0.115987
# 5509 -0.381286    0.640246  -1.068243     -1.598790   0.822432    -0.625201
# 5510 -1.632356    0.377342  -1.068243     -1.598790   2.244850    -0.115987
# 5511 -1.655595   -0.506972  -1.068243     -1.598790   0.822432     0.393228
#
#       Engine_cc     Seats
# 0      0.731579 -0.348225
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
# Price distribution
plt.figure(figsize=(8,5))
sns.histplot(df['Price_in_rupees'], bins=50, kde=True)
plt.title("Car Price Distribution")
plt.xlabel("Price (₹)")
plt.show()
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 8377 (\N{INDIAN RUPEE SIGN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Fuel type vs Price
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='fuel_type', y='Price_in_rupees')
plt.title("Price by Fuel Type")
plt.xticks(rotation=30)
plt.show()

# %%
# Manufacture year vs Price
plt.figure(figsize=(9,5))
sns.scatterplot(data=df, x='Manufacture', y='Price_in_rupees', alpha=0.4)
plt.title("Price vs Manufacture Year")
plt.show()

# %%
# Kms driven vs Price
plt.figure(figsize=(9,5))
sns.scatterplot(data=df, x='Kms_driven', y='Price_in_rupees', alpha=0.4)
plt.title("Price vs Kms Driven")
plt.show()

# %%
# Transmission vs Price
plt.figure(figsize=(6,5))
sns.boxplot(data=df, x='Transmission', y='Price_in_rupees')
plt.title("Price by Transmission")
plt.show()

# %%
# Correlation heatmap (sirf numeric columns)
plt.figure(figsize=(7,6))
numeric_cols = df[['Kms_driven','Ownership','Manufacture','Engine_cc','Seats','Price_in_rupees']]
sns.heatmap(numeric_cols.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # TRAIN_TEST_SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)*100,lr.score(x_test,y_test)*100
# Out:
# (34.87016451244609, 36.3911104488659)

# %%
mean_squared_error(y_test,lr.predict(x_test)),mean_absolute_error(y_test,lr.predict(x_test))
# Out:
# (2561661634201.876, 772772.3501363823)

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
dt.score(x_train,y_train)*100,dt.score(x_test,y_test)*100
# Out:
# (99.99999857169713, 74.97253852163945)

# %%
mean_squared_error(y_test,dt.predict(x_test)),mean_absolute_error(y_test,dt.predict(x_test))
# Out:
# (1007907673329.8912, 291670.3191296464)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)*100,rf.score(x_test,y_test)*100
# Out:
# (98.25424509749399, 85.55935209731426)

# %%
mean_squared_error(y_test,rf.predict(x_test)),mean_absolute_error(y_test,rf.predict(x_test))
# Out:
# (581554778999.7273, 252801.43586884253)

# %%
# Actual vs Predicted scatter — sabse important graph model ke liye
y_pred = rf.predict(x_test)

plt.figure(figsize=(7,7))
plt.scatter(y_test, y_pred, alpha=0.4)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Price (₹)")
plt.ylabel("Predicted Price (₹)")
plt.title("Actual vs Predicted Price")
plt.show()
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 8377 (\N{INDIAN RUPEE SIGN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Residual plot — errors kahan zyada hain, ye dikhata hai
residuals = y_test - y_pred

plt.figure(figsize=(8,5))
sns.scatterplot(x=y_pred, y=residuals, alpha=0.4)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Price (₹)")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("Residual Plot")
plt.show()
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 8377 (\N{INDIAN RUPEE SIGN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Feature importance — kaunsa feature sabse zyada matter karta hai
importance_df = pd.DataFrame({
    'feature': x.columns,
    'importance': rf.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(8,5))
sns.barplot(data=importance_df, x='importance', y='feature')
plt.title("Feature Importance (Random Forest)")
plt.show()

# %%
# Model comparison — lr, dt, rf teeno ka R2 side by side
model_scores = pd.DataFrame({
    'Model': ['Linear Regression', 'Decision Tree', 'Random Forest'],
    'Train R2': [lr.score(x_train,y_train)*100, dt.score(x_train,y_train)*100, rf.score(x_train,y_train)*100],
    'Test R2':  [lr.score(x_test,y_test)*100, dt.score(x_test,y_test)*100, rf.score(x_test,y_test)*100]
})

model_scores.set_index('Model').plot(kind='bar', figsize=(8,5))
plt.title("Model Comparison (Train vs Test R2)")
plt.ylabel("R2 Score (%)")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # PREDITION_FUNCTION

# %%
x_test
# Out:
#       car_name  Kms_driven  fuel_type  Transmission  Ownership  Manufacture  \
# 5013  0.608336    1.114979  -1.068243      0.625473   0.822432     0.393228
# 4462  0.941438    0.401242   0.918538     -1.598790   2.244850     0.393228
# 79   -0.433576   -0.961079   0.918538      0.625473  -0.599986    -0.370594
# 5343 -1.256648    2.074269  -1.068243      0.625473  -0.599986    -0.625201
# 1223  0.346890   -0.459171  -1.730503      0.625473  -0.599986     0.138621
# ...        ...         ...        ...           ...        ...          ...
# 4602  0.106747    0.771435   0.918538      0.625473  -0.599986    -0.115987
# 3968  0.931755   -0.046699  -1.068243      0.625473  -0.599986    -1.134416
# 1001  0.800064    0.532001  -1.068243     -1.598790   0.822432    -0.879809
# 3203  1.092496   -0.178485   0.918538      0.625473  -0.599986     0.902442
# 4322 -0.437449    0.445864  -1.068243      0.625473   3.667268    -0.115987
#
#       Engine_cc     Seats
# 5013  -0.922545 -0.348225
# ...

# %%
y_test
# Out:
# 5013     631000
# 4462     308000
# 79       465000
# 5343     260000
# 1223     725000
#          ...
# 4602     199000
# 3968     230000
# 1001    1121000
# 3203     502000
# 4322     385000
# Name: Price_in_rupees, Length: 1103, dtype: int64

# %%
rf.predict([[0.608336,1.114979,-1.068243,0.625473,0.822432,0.393228,-0.922545,-0.348225]])
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([650430.])

# %%
rf.predict([[0.941438,0.401242,0.918538,-1.598790,2.244850,0.393228,-1.568310,-0.348225]])
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([3743190.])

# %%
rf.predict([[-0.433576,-0.961079,0.918538,0.625473,-0.599986,-0.370594,-0.578943,-0.348225]])
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([444280.])

# %%
rf.predict([[-1.256648,2.074269,-1.068243,0.625473,-0.599986,-0.625201,1.116621,2.429515]])
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([363480.])

# %%
rf.predict([[0.346890,-0.459171,-1.730503,0.625473,-0.599986,0.138621,-0.230161,-0.348225]])
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([477820.])

# %%
rf.predict([[0.106747,0.771435,0.918538,0.625473,-0.599986,-0.115987,-0.813767,-0.348225]])
# Out:
# /Users/hemantjain/Old_Car_Price_Prediction_Model/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([282220.])

# %% [markdown]
# # NEW _DATA

# %%
new_data = pd.DataFrame([['Honda Jazz VX CVT',26696,'Petrol','Automatic',1,2018,1199,5]],columns=x_train.columns)

# %%
new_data
# Out:
#             car_name  Kms_driven fuel_type Transmission  Ownership  \
# 0  Honda Jazz VX CVT       26696    Petrol    Automatic          1
#
#    Manufacture  Engine_cc  Seats
# 0         2018       1199      5

# %% [markdown]
# ### ENCODING

# %%
new_data['car_name']=car_name_le.transform(new_data['car_name'])
new_data['fuel_type']=fuel_type_le.transform(new_data['fuel_type'])
new_data['Transmission']=Transmission_le.transform(new_data['Transmission'])

# %%
new_data
# Out:
#    car_name  Kms_driven  fuel_type  Transmission  Ownership  Manufacture  \
# 0       385       26696          4             0          1         2018
#
#    Engine_cc  Seats
# 0       1199      5

# %% [markdown]
# ### SCALING

# %%
new_data = pd.DataFrame(ss.transform(new_data), columns=new_data.columns)

# %%
new_data
# Out:
#    car_name  Kms_driven  fuel_type  Transmission  Ownership  Manufacture  \
# 0 -1.030061   -0.872744   0.918538      -1.59879  -0.599986     0.647835
#
#    Engine_cc     Seats
# 0   -0.57549 -0.348225

# %% [markdown]
# ### PREDICTION

# %%
rf.predict(new_data)
# Out:
# array([876370.])
